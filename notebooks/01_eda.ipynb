# %% [markdown]
# ## Init

# %%
import pandas as pd
import numpy as np

train = pd.read_csv("../data/raw/train.csv")
test  = pd.read_csv("../data/raw/test.csv")
orig  = pd.read_csv("../data/raw/original.csv")

# %% [markdown]
# ## EDA

# %%
train['Churn'] = train['Churn'].map({'Yes': 1, 'No': 0})

# %%
train["Churn"].sum()/train["Churn"].count()
# Out:
# np.float64(0.225207592133209)

# %%
print(train.dtypes.value_counts())
print(f"\nTotal features: {train.shape[1]}")
# Out:
# str        15
# int64       4
# float64     2
# Name: count, dtype: int64
#
# Total features: 21

# %%
# Run this
print(train.select_dtypes(include='str').columns.tolist())
print(train.select_dtypes(include=['int64','float64']).columns.tolist())
# Out:
# ['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod']
# ['id', 'SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges', 'Churn']

# %%
# Cardinality of each string column
for col in train.select_dtypes(include='str').columns:
    print(f"{col}: {train[col].nunique()} unique → {train[col].unique()}")
# Out:
# gender: 2 unique → <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str
# Partner: 2 unique → <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# Dependents: 2 unique → <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# PhoneService: 2 unique → <StringArray>
# ['Yes', 'No']
# Length: 2, dtype: str
# MultipleLines: 3 unique → <StringArray>
# ['No', 'Yes', 'No phone service']
# Length: 3, dtype: str
# InternetService: 3 unique → <StringArray>
# ['DSL', 'Fiber optic', 'No']
# Length: 3, dtype: str
# OnlineSecurity: 3 unique → <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# OnlineBackup: 3 unique → <StringArray>
# ['No', 'Yes', 'No internet service']
# Length: 3, dtype: str
# DeviceProtection: 3 unique → <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# TechSupport: 3 unique → <StringArray>
# ['Yes', 'No', 'No internet service']
# Length: 3, dtype: str
# StreamingTV: 3 unique → <StringArray>
# ...
